# %% [markdown]
# ![Intro.png](data:image/png;base64,...)

# %% [markdown]
# # <font size="50" color="lighblue">Análisis exploratorio de datos: </font><br> <font size="6" color="lighblue">Vectores NumPy para computación numérica optimizada y Pandas <br> Curso de AI</font>

# %% [markdown]
# ## <font size="6" color="lighblue">Descripción del capítulo</font>
#
# ### *Descripción de los objetivos:*
# * Comprender el uso preciso de NumPy y ser capaz de procesar datos de manera eficiente.
# * Aprender los conceptos básicos de los vectores NumPy, la indexación y la división de NumPy (slicing) y las diversas formas de su aplicación.
# * Aprender a crear y manejar series y objetos de marcos de datos (data frame objects).
# * Conocer los métodos apropiados de ejecución óptima del modelo para el preprocesamiento de datos utilizando la librería Pandas para explorar y convertir datos.
# * Ser capaz de encontrar el método de análisis adecuado implementando una visualización de datos adecuada para la escala de datos.
#
# ### *Contenidos del capítulo*
# * Unidad 1. Estructura de datos de matriz NumPy para un rendimiento computacional óptimo
# * **Unidad 2.** Exploración óptima de datos a través de Pandas
# * Unidad 3. Preprocesamiento de datos de Pandas para una ejecución óptima del modelo
# * Unidad 4. Visualización de datos para varias escalas de datos

# %% [markdown]
# # **Unidad 2:** Exploración óptima de datos a través de Pandas
#
# 2.1. Pipelines: estructuras de datos según tipos de datos<br>
# 2.2. Serie Pandas y DataFrames<br>
# 2.3. Fusionar y vincular marcos de datos<br>
# **2.4. Clasificación de marcos de datos y índice múltiple**<br>
# 2.5. Examinar las características de los datos mediante estadísticas descriptivas y muestras de datos<br>

# %% [markdown]
# ## 2.4. Clasificación de Marco de datos e Índice múltiple
# ### Manipulación de Marco de datos
# #### Ordenar:
# * Es posible ordenar las filas de un Marco de datos usando una o más columnas.

# %%
import pandas as pd
import numpy as np
import os

# %%
## ADVERTENCIA: Comentar esta celda si NO está trabajando dentro de Google Colaboratory
from google.colab import drive
drive.mount('/content/drive')
os.getcwd()
os.chdir("/content/drive/MyDrive/Ejercicio_Febrero_2024") ## Cambie esta ruta por la de su sistema de archivos
os.getcwd()
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/Ejercicio_Febrero_2024'

# %%
# En Jupyter: Dirígete al directorio donde se encuentra el archivo de datos.
try:
  os.chdir(r'~~') # Por favor, reemplaza la ruta en tu PC a 'data_studentlist.csv'
except:
  print('archivo no encontrado')

# %%
df = pd.read_csv('data_studentlist.csv')

# %%
df.head()
# Out:
#               Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 0    Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1   Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2     Brian Martin      M   24      4       N         B   175.0    80.1
# 3     David Hassel      M   23      3       N        AB   182.1    85.7
# 4  Clara Rodriquez      F   20      1       Y         A   168.0    49.5

# %%
df.sort_values(by='Bloodtype')
df.sort_values(by='Bloodtype',ascending=False)
df.sort_values(by=['Bloodtype','Gender'])
# Out:
#                 Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0

# %%
testdf=df.sort_values(by=['Height'], ascending=False)

# %%
testdf.head()
# Out:
#                 Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1

# %%
testdf.reset_index(drop=True)
# Out:
#                 Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 0       David Hassel      M   23      3       N        AB   182.1    85.7
# 1       John Matsuda      M   22      2       N        AB   180.0    75.8
# 2       John Bertsch      M   23      3       N         B   178.5    64.2
# 3    Margareth Jones      F   23      1       N         A   176.9    55.0
# 4   Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 5     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 6       Brian Martin      M   24      4       N         B   175.0    80.1
# 7     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 8        Andrew King      M   21      1       N         A   169.2    62.2
# 9     Richard Swayze      M   24      4       Y         B   168.6    70.2
# 10   Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 11     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 12     Jared Diamond      M   23      3       Y         O   165.3    68.2
# 13      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 14  Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 15      Linda Carter      F   22      2       N         B   158.2    45.2
# 16       Susan Clark      F   22      1       N         O   155.2    45.3

# %% [markdown]
# **$</>$ Línea [5-1]**<br>
# * Ordenar en orden ascendente.<br>
#
# **$</>$ Línea [5-2]**<br>
# * Ordenar en orden descendente.<br>
#
# **$</>$ Línea [5-3]**<br>
# * Ordenar usando dos columnas.

# %% [markdown]
# #### Indexación jerárquica con Índice múltiple

# %%
['G1']*3
# Out:
# ['G1', 'G1', 'G1']

# %%
['G2']*3
# Out:
# ['G2', 'G2', 'G2']

# %%
['G1']*3+['G2']*3
# Out:
# ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']

# %%
[1,2,3]*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
my_header=['a','b','c']
my_index_out=['G1']*3 + ['G2']*3
my_index_in=[1,2,3]*2
list(zip(my_index_out, my_index_in))
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
my_header=['a','b','c']
my_index_out=['G1']*3 + ['G2']*3
my_index_in=[1,2,3]*2
my_index_zipped= list(zip(my_index_out, my_index_in))
my_index=pd.MultiIndex.from_tuples(my_index_zipped)
df=pd.DataFrame (data=np.random.randn(6,3),index=my_index, columns=my_header)
df
# Out:
#              a         b         c
# G1 1  0.399337  1.084150 -1.050685
#    2  1.681078  0.531506  0.311358
#    3 -2.597574 -0.796140  0.939561
# G2 1 -1.328639  0.521642  0.601722
#    2  0.696752 -1.870670  1.954097
#    3  1.610281 -1.144587  1.177589

# %% [markdown]
# **$</>$ Línea [6-1]**<br>
# Nombres de columnas<br>
# **$</>$ Línea [6-2]**<br>
# Etiquetas para la capa exterior<br>
# **$</>$ Línea [6-3]**<br>
# Etiquetas para las capas interiores.<br>
# **$</>$ Línea [6-4]**<br>
# Crea una lista de tuplas con las etiquetas.<br>
# **$</>$ Línea [6-5]**<br>
# Crear el Índice múltiple<br>
# **$</>$ Línea [6-6]**<br>
# Aplicar el Índice múltiple

# %% [markdown]
# # Ejercicio de codificación #0108
# ### 1. MultiIndex:

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 1.1. Creando un DataFrame con MultiIndex:

# %%
my_index_out = ['G1']*2 + ['G2']*2 + ['G3']*2
my_index_in = ['a', 'b']*3
list(zip(my_index_out, my_index_in))
# Out:
# [('G1', 'a'), ('G1', 'b'), ('G2', 'a'), ('G2', 'b'), ('G3', 'a'), ('G3', 'b')]

# %%
my_header = ['A','B','C']
my_index_out = ['G1']*2 + ['G2']*2 + ['G3']*2
my_index_in = ['a', 'b']*3
my_index_zipped = list(zip(my_index_out, my_index_in))
my_index_zipped
my_multi_index = pd.MultiIndex.from_tuples(my_index_zipped)
df = pd.DataFrame(data=np.random.randn(6,3),index=my_multi_index,columns=my_header)
df
# Out:
#              A         B         C
# G1 a -0.885115 -0.832450 -3.118038
#    b -0.786351 -0.725685 -0.020373
# G2 a  0.784049  1.339340 -0.927481
#    b -1.328092  0.853920 -2.707523
# G3 a -0.832851  2.163201  0.099533
#    b  1.630672 -1.702962 -0.673125

# %% [markdown]
# #### 1.2. Indexación y división de DataFrames con MultiIndex:

# %%
df.loc['G1']
# Out:
#           A         B         C
# a -0.885115 -0.832450 -3.118038
# b -0.786351 -0.725685 -0.020373

# %% [markdown]
# # Indexación seguida de otra indexación.

# %%
df.loc['G1'].loc['a']
# Out:
# A   -0.885115
# B   -0.832450
# C   -3.118038
# Name: a, dtype: float64

# %% [markdown]
# # Indexación seguida de otra indexación.

# %%
df.loc['G1'].loc['a','B']
# Out:
# -0.8324502399423691

# %% [markdown]
# ### 2. Resumen del marco de datos:
# #### 2.1. Agrupar por método:
# # Dirígente al directorio donde se encuentra el archivo de datos.

# %%
# En Jupyter: Dirígete al directorio donde se encuentra el archivo de datos.
try:
  os.chdir(r'~~') # Por favor, reemplaza la ruta en tu PC a 'data_studentlist.csv'
except:
  print('archivo no encontrado')

# %%
df = pd.read_csv('data_studentlist.csv',header='infer')
df.head(5)
# Out:
#               Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 0    Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1   Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2     Brian Martin      M   24      4       N         B   175.0    80.1
# 3     David Hassel      M   23      3       N        AB   182.1    85.7
# 4  Clara Rodriquez      F   20      1       Y         A   168.0    49.5

# %%
# error!!!
# df.groupby('gender').mean()

# %%
df.groupby('Gender')['Height'].mean()
# Out:
# Gender
# F    166.642857
# M    172.410000
# Name: Height, dtype: float64

# %%
df.groupby('Gender')[['Height','Weight']].mean()
# Out:
#             Height     Weight
# Gender
# F       166.642857  50.442857
# M       172.410000  68.500000

# %%
df.groupby('Gender')[['Grade','Age']].std()
# Out:
#            Grade       Age
# Gender
# F       0.755929  1.069045
# M       1.159502  1.159502

# %%
df.groupby('Gender')['Height'].describe()
# Out:
#         count        mean       std    min      25%    50%    75%    max
# Gender
# F         7.0  166.642857  8.487414  155.2  160.100  168.0  173.1  176.9
# M        10.0  172.410000  6.804647  162.2  167.475  172.1  177.9  182.1

# %%
sr = df.groupby(['Gender','Bloodtype'])['Height'].mean()     # MultiIndexed result.
sr
# Out:
# Gender  Bloodtype
# F       A            172.450000
#         AB           170.100000
#         B            158.200000
#         O            164.433333
# M       A            165.700000
#         AB           181.050000
#         B            174.550000
#         O            166.200000
# Name: Height, dtype: float64

# %%
sr.loc['F']
# Out:
# Bloodtype
# A     172.450000
# AB    170.100000
# B     158.200000
# O     164.433333
# Name: Height, dtype: float64

# %%
sr.loc['F'].loc['A']
# Out:
# 172.45

# %% [markdown]
# #### 2.2.  Métodos de DataFrame:

# %%
df['height'].apply(lambda x: x/100)
# Out:
# 0     1.653
# 1     1.701
# 2     1.750
# 3     1.821
# 4     1.680
# 5     1.620
# 6     1.552
# 7     1.769
# 8     1.785
# 9     1.761
# 10    1.671
# 11    1.800
# 12    1.622
# 13    1.761
# 14    1.582
# 15    1.686
# 16    1.692
# Name: height, dtype: float64

# %%
df.sort_values(by='Bloodtype')
# Out:
#                 Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 16       Andrew King      M   21      1       N         A   169.2    62.2

# %%
df.sort_values(by='Bloodtype', ascending=False)
# Out:
#                 Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 16       Andrew King      M   21      1       N         A   169.2    62.2

# %%
df.sort_values(by=['Bloodtype','Gender'])
# Out:
#                 Name Gender  Age  Grade Absence Bloodtype  Height  Weight
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0

# %%
df['Bloodtype'].unique()
# Out:
# array(['O', 'AB', 'B', 'A'], dtype=object)

# %%
df['Bloodtype'].nunique()
# Out:
# 4

# %%
# Tabla de frecuencias
df['Bloodtype'].value_counts()
# Out:
# O     5
# B     5
# A     4
# AB    3
# Name: Bloodtype, dtype: int64

# %%
# Tabla de frecuencias
df['Gender'].value_counts()
# Out:
# M    10
# F     7
# Name: Gender, dtype: int64

# %% [markdown]
# #### 2.3. Pivoting:

# %%
my_dict = {"Size": ["L", "L", "M", "M", "M", "S", "S", "S", "S"],
           "Type": ["A", "A", "A", "B", "B", "A", "A", "B", "B"],
            "Location": ["L1", "L1", "L1", "L2", "L2", "L1", "L2", "L2", "L1"],
            "A": [1, 2, 2, 3, 3, 4, 5, 6, 7],
            "B": [2, 4, 5, 5, 6, 6, 8, 9, 9]}
df = pd.DataFrame(my_dict)
df
# Out:
#   Size Type Location  A  B
# 0    L    A       L1  1  2
# 1    L    A       L1  2  4
# 2    M    A       L1  2  5
# 3    M    B       L2  3  5
# 4    M    B       L2  3  6
# 5    S    A       L1  4  6
# 6    S    A       L2  5  8
# 7    S    B       L2  6  9
# 8    S    B       L1  7  9

# %%
# Índice por 'Tamaño' y 'Tipo'. Columnas por 'Ubicación'. Valores proporcionados por la columna 'B'.
dfr = pd.pivot_table(df, index=['Size', 'Type'], columns='Location', values='B')
dfr
# Out:
# Location    L1   L2
# Size Type
# L    A     3.0  NaN
# M    A     5.0  NaN
#      B     NaN  5.5
# S    A     6.0  8.0
#      B     9.0  9.0

# %%
dfr.columns
# Out:
# Index(['L1', 'L2'], dtype='object', name='Location')

# %%
dfr.index
# Out:
# MultiIndex([('L', 'A'),
#             ('M', 'A'),
#             ('M', 'B'),
#             ('S', 'A'),
#             ('S', 'B')],
#            names=['Size', 'Type'])

# %%
# Lo mismo que arriba, pero completa los valores faltantes con 0.
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# Lo mismo que arriba con la función de agregación especificada.
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.mean, fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# Índice por ''Ubicación'. Columnas por 'Tamaño' y 'Tipo'. Valores proporcionados por la columna 'B'.
dfr = pd.pivot_table(df, index='Location', columns=['Size','Type'], values='B')
dfr
# Out:
# Size        L    M         S
# Type        A    A    B    A    B
# Location
# L1        3.0  5.0  NaN  6.0  9.0
# L2        NaN  NaN  5.5  8.0  9.0

# %%
dfr.index
# Out:
# Index(['L1', 'L2'], dtype='object', name='Location')

# %%
dfr.columns
# Out:
# MultiIndex([('L', 'A'),
#             ('M', 'A'),
#             ('M', 'B'),
#             ('S', 'A'),
#             ('S', 'B')],
#            names=['Size', 'Type'])

# %%
# La función de agregación es numpy.median().
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.median, fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# Promedios de grupo de las columnas 'A' y 'B'.
pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc=np.mean)
# Out:
#              A    B
# Size Type
# L    A     1.5  3.0
# M    A     2.0  5.0
#      B     3.0  5.5
# S    A     4.5  7.0
#      B     6.5  9.0

# %%
# Ahora, con el método groupby().
# El resultado es el mismo.
df.groupby(['Size','Type'])[['A','B']].mean()
# Out:
#              A    B
# Size Type
# L    A     1.5  3.0
# M    A     2.0  5.0
#      B     3.0  5.5
# S    A     4.5  7.0
#      B     6.5  9.0

# %%
# Agregue de manera diferente las columnas 'A' y 'B'.
pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc={'A':np.max,'B':np.min})
# Out:
#            A  B
# Size Type
# L    A     2  2
# M    A     2  5
#      B     3  5
# S    A     5  6
#      B     7  9
